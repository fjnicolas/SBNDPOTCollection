# %% [markdown]
# ## Imports
# Update the path to the SBND-RunCo repository on your machine

# %%
from datetime import datetime, timedelta, timezone
import matplotlib.pyplot as plt
import sys

# Import functions
sys.path.append('include/')
import livetime
import sbnd_daqrun_spreadsheet
import plotting_macros

# Set the style for the plots
plt.style.use('include/style.mplstyle')

# Delete after testing
import importlib

# %% [markdown]
# ## Extract the Livetime Info
# - Update run numbers and uptime from the Google spreadsheet
# - This step calculates the livetime (POT and spills) per interval of time according to the settings above. This relies on `starts.txt` and `ends.txt`, which contain the timestamps copied directly from the DAQ Runs spreadsheet (natively in UTC).

# %%
importlib.reload(sbnd_daqrun_spreadsheet)
importlib.reload(livetime)

current_time = datetime.now(timezone.utc)
print(f"Current time (UTC): {current_time}")

# Run1 - completed, no need to update
#sbnd_daqrun_spreadsheet.update_daq_runs("run1")
# livetime.extract_livetime_info("run1", current_time)

# Run2 - ongoing, update the spreadsheet with the latest information
sbnd_daqrun_spreadsheet.update_daq_runs("run2", verbose=True)
livetime.extract_livetime_info("run2", current_time, verbose=True)
# Out:
# Current time (UTC): 2026-04-20 21:05:30.053715+00:00
# Downloading DAQ runs spreadsheet to: /Users/franciscojaviernicolas/Work/SBNDRunCo/SBNDPOTCollection/data/download_DAQRuns_run2.csv
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1LfNJ11Bbob8WQSgDakEVNZQ-OBHmskYqF0NADQM9kJM/export?format=csv&gid=1379562188
# To: /Users/franciscojaviernicolas/Work/SBNDRunCo/SBNDPOTCollection/data/download_DAQRuns_run2.csv
# 520kB [00:00, 82.1MB/s]
#      Run           Start time             End time
# 0  19549  2025-10-02 22:42:37  2025-10-02 23:00:04
# 1  19550  2025-10-02 23:12:17  2025-10-03 13:41:13
# 2  19551  2025-10-03 15:04:52  2025-10-03 15:29:32
# 3  19552  2025-10-03 16:48:34  2025-10-03 16:50:14
# 4  19554  2025-10-03 22:58:00  2025-10-03 23:15:24
#        Run           Start time             End time
# 500  20071  2026-04-14 20:33:36  2026-04-16 10:02:43
# 501  20072  2026-04-16 10:12:17  2026-04-16 16:05:41
# 502  20073  2026-04-16 16:12:29  2026-04-16 16:25:51
# 503  20074  2026-04-16 16:31:43  2026-04-18 10:29:25
# 504  20075  2026-04-18 10:37:05    Running (3508:11)
# Saved run numbers to /Users/franciscojaviernicolas/Work/SBNDRunCo/SBNDPOTCollection/data/runNums_run2.txt
# Saved start times to /Users/franciscojaviernicolas/Work/SBNDRunCo/SBNDPOTCollection/data/starts_run2.txt
# Saved end times to /Users/franciscojaviernicolas/Work/SBNDRunCo/SBNDPOTCollection/data/ends_run2.txt
#                          start                       end      livetime  \
# 1117 2026-04-20 04:00:00+00:00 2026-04-20 08:00:00+00:00  14400.000000
# 1118 2026-04-20 08:00:00+00:00 2026-04-20 12:00:00+00:00  14400.000000
# 1119 2026-04-20 12:00:00+00:00 2026-04-20 16:00:00+00:00  14400.000000
# 1120 2026-04-20 16:00:00+00:00 2026-04-20 20:00:00+00:00  14400.000000
# 1116  353960.348677         NaN           NaN
# 1117  354416.199921         NaN           NaN
# 1118  348213.827890         NaN           NaN
# 1119  293585.542729         NaN           NaN
# 1120  344138.038246         NaN           NaN
# 1121   97694.715622         NaN           NaN

# %% [markdown]
# ## Weekly plots: DAQ Uptime and POT Collection Efficiency
#
# ##
# This plots the DAQ uptime, or fraction of time that the DAQ was being used. This does not include "expert" runs where the run was not logged in the spreadsheet (this appears like downtime). Please note that this may cause lower than "actual" uptimes!
#
# ##
# This plots the POT collection efficiency, which represents the fraction of POT delivered by AD to the BNB that SBND was online and capable of taking physics-quality data for.

# %%
importlib.reload(plotting_macros)

# Plot start/end and the interval delta
# Run 1:
#run_period = "run1"
#plot_start = datetime.strptime('2024-12-09 00:00:00', '%Y-%m-%d %H:%M:%S').replace(tzinfo=timezone.utc)
#plot_end = datetime.strptime('2025-07-12 00:00:00', '%Y-%m-%d %H:%M:%S').replace(tzinfo=timezone.utc)

# Run 2:
run_period = "run2"
plot_start = datetime.strptime('2026-04-10 13:00:00', '%Y-%m-%d %H:%M:%S').replace(tzinfo=timezone.utc)
plot_end = datetime.strptime('2026-04-17 15:00:00', '%Y-%m-%d %H:%M:%S').replace(tzinfo=timezone.utc)


## DAQ uptime
plotting_macros.plot_weekly_livetime(plot_start, plot_end, run_period)

## POT efficiency
plotting_macros.plot_weekly_potefficiency(plot_start, plot_end, run_period)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 16
#      12 plot_end = datetime.strptime('2026-04-17 15:00:00', '%Y-%m-%d %H:%M:%S').replace(tzinfo=timezone.utc)
#      13
#      14
#      15 ## DAQ uptime
# ---> 16 plotting_macros.plot_weekly_livetime(plot_start, plot_end, run_period)
#      17
#      18 ## POT efficiency
#      19 plotting_macros.plot_weekly_potefficiency(plot_start, plot_end, run_period)
#
# File ~/Work/SBNDRunCo/SBNDPOTCollection/include/plotting_macros.py:86, in plot_weekly_livetime(plot_start, plot_end, run_period)
#      83 ax.text(x=ax.get_xlim()[0] + deltaX, y=1.04*ax.get_ylim()[1], s=timestamp, fontsize=8, color='#d67a11', ha='right', va='top')
#      85 # Save the figure
# ---> 86 figure.savefig(str(PLOT_DIR) + '/daq_weekly_livetime.png', dpi=1000, bbox_inches='tight')
#      87 figure.savefig(str(PLOT_DIR) + '/daq_weekly_livetime.pdf', dpi=1000, bbox_inches='tight')
#      88 figure.savefig(str(PLOT_DIR) + '/daq_weekly_livetime_light.png', dpi=75, bbox_inches='tight')
#
# File ~/Work/SBNDRunCo/SBNDPOTCollection/venv-sbndpot/lib/python3.13/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File ~/Work/SBNDRunCo/SBNDPOTCollection/venv-sbndpot/lib/python3.13/site-packages/matplotlib/backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File ~/Work/SBNDRunCo/SBNDPOTCollection/venv-sbndpot/lib/python3.13/site-packages/matplotlib/backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File ~/Work/SBNDRunCo/SBNDPOTCollection/venv-sbndpot/lib/python3.13/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/Work/SBNDRunCo/SBNDPOTCollection/venv-sbndpot/lib/python3.13/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/Work/SBNDRunCo/SBNDPOTCollection/venv-sbndpot/lib/python3.13/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File ~/Work/SBNDRunCo/SBNDPOTCollection/venv-sbndpot/lib/python3.13/site-packages/PIL/Image.py:2708, in Image.save(self, fp, format, **params)
#    2706         fp = builtins.open(filename, "r+b")
#    2707     else:
# -> 2708         fp = builtins.open(filename, "w+b")
#    2709 else:
#    2710     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/franciscojaviernicolas/Work/SBNDRunCo/SBNDPOTCollection/plots/daq_weekly_livetime.png'

# %% [markdown]
# # Run 2 Cumulative

# %%
importlib.reload(plotting_macros)
plotting_macros.plot_run2_cumulative(plot_end)
# Out:
# Hit  17.5 at  2026-02-04 04:00:00+00:00  +  1.53129760648845 hours
# 	 17.48904626698383 17.517659210593894
# Total Delivered POT: 265758695.44964576

# %% [markdown]
# # Run 1 + Run 2 Cumulative

# %%
importlib.reload(plotting_macros)
plotting_macros.plot_total_cumulative(plot_end, True)
# Out:
# Hit  52.5 at  2026-01-27 00:00:00+00:00  +  2.5503086915428437 hours
# 	 52.47832886714159 52.512318686382336
# Mean collected POT in the slope calculation period: 311761.0670782434
# Mean delivered POT in the slope calculation period:  318610.46684699645
# Total Delivered POT: 640331833.5135262
